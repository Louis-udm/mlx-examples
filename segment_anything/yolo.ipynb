# %%
from utils import (
    ocr_text_from_yolo_results,
    show_mask,
    show_points,
    show_box,
    load_img,
    show_img_with_point,
)
from ultralytics import YOLO
import cv2

# %%
import os
os.getcwd()
import sys
sys.path
# sys.version
# Out:
# ['/Users/zlu/Projects/mlx-examples',
#  '/Users/zlu/Projects/mlx-examples/segment_anything',
#  '/Users/zlu/.pyenv/versions/3.10.13/lib/python310.zip',
#  '/Users/zlu/.pyenv/versions/3.10.13/lib/python3.10',
#  '/Users/zlu/.pyenv/versions/3.10.13/lib/python3.10/lib-dynload',
#  '',
#  '/Users/zlu/Projects/mlx-examples/.venv/lib/python3.10/site-packages']

# %%
# from roboflow import Roboflow
# rf = Roboflow(api_key="jyL4bQg28eekCd1Z6nMs")
# project = rf.workspace("zhibinlu").project("tabulation")
# dataset = project.version(3).download("yolov8")

# %%
data_path="/Users/zlu/Projects/mlx-examples/segment_anything/images/tabulation.v3i.yolov8/data.yaml"
# !yolo task=detect \
mode=train \
model=yolov8n.pt \
# data={dataset.location}/data.yaml \
data=data_path \
epochs=50 \
imgsz=730
# Out:
# WARNING ⚠️ 'data' is missing. Using default 'data=coco8.yaml'.
# New https://pypi.org/project/ultralytics/8.1.1 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.1.0 🚀 Python-3.10.13 torch-2.1.2 CPU (Apple M2 Pro)
# ...

# %%
img, img_path = load_img(0)
img_path="/Users/zlu/Projects/mlx-examples/"+img_path
# print(img_path)
# !yolo task=detect \
mode=predict \
model=/Users/zlu/Projects/mlx-examples/runs/detect/train14/weights/best.pt \
conf=0.25 \
source=/Users/zlu/Projects/mlx-examples/segment_anything/images
# Out:
# Corrupt JPEG data: premature end of data segment
# Ultralytics YOLOv8.1.0 🚀 Python-3.10.13 torch-2.1.2 CPU (Apple M2 Pro)
# Model summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
#
# image 1/20 /Users/zlu/Projects/mlx-examples/segment_anything/images/dog.jpg: 448x640 1 person, 1 dog, 1 bowl, 1 chair, 48.9ms
# image 2/20 /Users/zlu/Projects/mlx-examples/segment_anything/images/groceries.jpg: 448x640 1 car, 1 truck, 44.1ms
# Corrupt JPEG data: premature end of data segment
# image 3/20 /Users/zlu/Projects/mlx-examples/segment_anything/images/pdf_table0.jpg: 640x512 (no detections), 47.6ms
# image 4/20 /Users/zlu/Projects/mlx-examples/segment_anything/images/pdf_table0_result.png: 640x512 (no detections), 45.6ms
# image 5/20 /Users/zlu/Projects/mlx-examples/segment_anything/images/pdf_table1.png: 640x512 (no detections), 43.3ms
# image 6/20 /Users/zlu/Projects/mlx-examples/segment_anything/images/pdf_table1_result.png: 640x512 (no detections), 43.3ms
# ...
